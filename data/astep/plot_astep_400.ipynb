# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
from astropy.table import Table, vstack
# %matplotlib notebook
t17 = ascii.read('betapic_astep_2017.csv')
t18 = ascii.read('betapic_astep_2018.csv')

# %%
tb = vstack([t17,t18])

# %%
plt.scatter(tb['BJD'], tb['FCAL1'])
plt.scatter(tb['BJD'], (tb['SUNELEV']<-15))
plt.scatter(tb['BJD'], tb['FLAG']*0.95)
plt.plot(tb['BJD'], tb['SKY']/200.)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
m_elev = (tb['SUNELEV']<-15.)
m_sky  = ( (tb['SKY']/200.) < 1)

m_all = m_elev * m_sky * tb['FLAG']



m_all = (m_elev * m_sky * tb['FLAG']).astype('bool')

# %%
plt.scatter(tb['BJD'], tb['FCAL1'])
plt.scatter(tb['BJD'], (tb['SUNELEV']<-15))
plt.scatter(tb['BJD'], m_all)

# %%
a=tb['BJD']
b=tb['FCAL1']

plt.scatter(a[m_all], b[m_all]   )
# Out:
# <img src="data:image/png;base64,..." width="986">

# %%
t = t18['BJD']
dt = t[2:]- t[0:-2]

# %%
plt.hist(dt,100,range=[0.001,0.003])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.2000e+01, 1.1000e+01, 1.1700e+02, 1.1550e+03, 6.8600e+02,
#         6.3400e+02, 3.3500e+02, 2.2400e+02, 1.4200e+02, 7.4000e+01,
#         8.1000e+01, 8.5000e+01, 8.3000e+01, 9.7000e+01, 1.3100e+02,
#         3.2300e+02, 2.0200e+02, 1.3200e+02, 1.1600e+02, 1.1200e+02,
#         8.5000e+01, 1.8900e+02, 9.5000e+01, 8.6000e+01, 1.8100e+02,
#         3.1800e+02, 1.3600e+02, 8.2000e+01, 7.1000e+01, 8.3000e+01,
#         6.2000e+01, 4.4000e+01, 4.8000e+01, 2.5000e+01, 1.7300e+02,
#         5.4000e+01, 9.9000e+01, 1.3212e+04, 1.5944e+04, 1.1387e+04,
#         6.9960e+03, 5.4550e+03, 3.2430e+03, 2.0110e+03, 1.2300e+03,
#         1.3440e+03, 5.7400e+02, 6.0200e+02, 8.8900e+02, 1.4240e+03,
#         2.0070e+03, 1.5070e+03, 9.8100e+02, 8.4500e+02, 7.4400e+02,
# ...

# %%
plt.hist?

# %%
dt = (t[2:]- t[0:-2])*86400.

# %%
plt.hist(dt,100,range=[150,180])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.900e+01, 8.000e+00, 1.600e+01, 1.800e+01, 9.000e+00, 2.000e+01,
#         1.200e+01, 9.000e+00, 9.000e+00, 2.200e+01, 1.800e+01, 8.000e+00,
#         7.000e+00, 1.100e+01, 1.200e+01, 1.500e+01, 2.900e+01, 1.000e+01,
#         9.000e+00, 8.000e+00, 1.000e+01, 1.300e+01, 1.100e+01, 1.100e+01,
#         1.400e+01, 1.100e+01, 7.000e+00, 2.000e+00, 9.000e+00, 4.000e+00,
#         9.000e+00, 7.000e+00, 1.000e+01, 1.000e+01, 5.000e+00, 7.000e+00,
#         3.000e+00, 2.000e+00, 2.000e+00, 9.000e+00, 5.000e+00, 9.000e+00,
#         3.000e+00, 7.000e+00, 5.000e+00, 5.600e+01, 8.500e+01, 2.700e+01,
#         2.200e+01, 1.000e+01, 5.000e+00, 1.000e+00, 1.000e+00, 2.000e+00,
#         2.100e+01, 2.900e+01, 2.000e+01, 1.300e+01, 1.800e+01, 4.000e+01,
#         8.200e+01, 4.500e+01, 3.857e+03, 8.160e+03, 1.691e+03, 3.319e+03,
#         3.721e+03, 3.623e+03, 2.606e+03, 1.698e+03, 1.514e+03, 1.564e+03,
# ...
